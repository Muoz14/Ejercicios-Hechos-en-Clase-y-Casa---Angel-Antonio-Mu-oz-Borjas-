# %%
import numpy as np
import pandas as pd

# %%
ruta = "C:/ResultadoVentasMotos.csv"
df = pd.read_csv(ruta)

df
# Out:
#      Modelo    Precio  Cantidad  Total_Vendido
# 0  Kawasaki  120000.0         2       240000.0
# 1    Ducati  300000.0         2       600000.0
